# %%
import os 
import pandas as pd 
from basicprocess import *

# %%
originalticket_folder = os.path.abspath(os.path.join(os.getcwd(), '..', '..', '2024_2025'))
newtaipei_mrtfolder = os.path.join(originalticket_folder,'臺北捷運每日各站分時OD資料(D)')
taipei_mrtfolder = os.path.join(originalticket_folder,'臺北捷運每日各站分時OD資料(D)')
df = pd.read_csv(findfiles(newtaipei_mrtfolder)[0], nrows = 100)

# %%
df
# Out:
#           旅次日期 旅次時段(Ex: 12表示為12時00分至12時59分) 票證分類 (N-IC: 非電子票證; IC: 電子票證)  \
# 0     TripDate                     TripHour                  TicketClass
# 1   2024-07-01                           11                           IC
# 2   2024-07-01                           10                           IC
# 3   2024-07-01                            9                           IC
# 4   2024-07-01                            8                           IC
# ..         ...                          ...                          ...
# 95  2024-07-01                           18                           IC
# 96  2024-07-01                            7                           IC
# 97  2024-07-01                            9                           IC
# 98  2024-07-01                           11                           IC
# 99  2024-07-01                           22                           IC
#
#       電子票證卡種        持卡身分             起站代碼             起站中文名稱  \
# ...

# %%
df.reindex(columns = ['起站代碼']).drop_duplicates()
# Out:
#                起站代碼
# 0   OriginStationID
# 1               R24
# 2               R03
# 3               Y10
# 4               R22
# ..              ...
# 84             BR02
# 91        G15 / O08
# 92              O14
# 94             BR20
# 97              G05
#
# [63 rows x 1 columns]
